# %% [markdown]
# # Exploratory Data Analysis (EDA) for Financial News Notebook
# ## What this notebook does is:
#
# - Load the data
# - Perform basic statistics on the data
# - Analyze the number of articles per publisher
# - Identify trends in publication dates

# %%
import os
import sys
import pandas as pd

# %%
# Get the current working directory of the project
current_dir = os.getcwd()
print(current_dir)

# Get the parent directory
parent_dir = os.path.dirname(current_dir)
print(parent_dir)

# Insert the path to the parent directory
sys.path.insert(0, parent_dir)

# # Insert the path to the Scripts directory
# sys.path.insert(0, os.path.join(parent_dir, 'Scripts'))

# print(sys.path)
# Out:
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis\notebooks
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis

# %%
# Import custom scripts

from scripts.descriptive_statistics import basic_statistics, articles_per_publisher, publication_trends
from scripts.text_analysis import sentiment_analysis, generate_wordcloud
from scripts.time_series_analysis import publication_frequency, publishing_times_analysis
from scripts.publisher_analysis import publisher_analysis, extract_domains
# Out:
# [nltk_data] Error loading vader_lexicon: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>

# %%
# Load data
file_path = '../data/raw_analyst_ratings/raw_analyst_ratings.csv'
df = pd.read_csv(file_path)

# %%
# Descriptive Statistics
print(basic_statistics(df, 'headline'))
articles_per_publisher(df, 'publisher')
publication_trends(df, 'date')
# Out:
# 2024-12-17 20:44:17,471 - INFO - Basic text statistics calculated successfully.
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: text_length, dtype: float64
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis\scripts\descriptive_statistics.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=publisher_counts.index, y=publisher_counts.values, palette="viridis")
# 2024-12-17 20:44:18,532 - INFO - Top 10 publishers plotted successfully.
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis\scripts\descriptive_statistics.py:95: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   df['year_month'] = df[date_col].dt.to_period('M')
# 2024-12-17 20:44:19,886 - INFO - Publication trends analyzed successfully.
# year_month
# 2011-04       6
# 2011-05      78
# 2011-06      96
# 2011-07     137
# 2011-08     149
#            ...
# 2020-02    2356
# 2020-03    4680
# 2020-04    4616
# 2020-05    9333
# 2020-06    5990
# Freq: M, Length: 111, dtype: int64

# %%
# Text Analysis
df = sentiment_analysis(df, 'headline')
generate_wordcloud(df, 'headline')

# %%
# Time Series Analysis
publication_frequency(df, 'date')
publishing_times_analysis(df, 'date')
# Out:
# hour
# 0.0       67
# 1.0       14
# 2.0       57
# 3.0       93
# 4.0     1469
# 5.0     1829
# 6.0     2476
# 7.0     5033
# 8.0     5527
# 9.0     5965
# 10.0    7669
# 11.0    5701
# 12.0    5732
# 13.0    2710
# 14.0    2075
# 15.0    1612
# 16.0    3939
# 17.0    2800
# 18.0     704
# 19.0     227
# 20.0     131
# 21.0      82
# 22.0      48
# 23.0      27
# Name: count, dtype: int64

# %%
# Publisher Analysis
publisher_analysis(df, 'publisher')
extract_domains(df, 'publisher')
# Out:
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis\scripts\publisher_analysis.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=publisher_counts.index[:10], x=publisher_counts.values[:10], orient='h', palette="coolwarm")
# 2024-12-17 20:54:53,503 - INFO - Publisher analysis completed successfully.
# c:\Users\HP\Desktop\KAIM-Cohort-3\Week 1\Nova Financial Solutions Financial News and Stock Price Analysis\scripts\publisher_analysis.py:88: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y=domain_counts.index[:10], x=domain_counts.values[:10], orient='h', palette="mako")
# 2024-12-17 20:54:55,875 - INFO - Domain extraction and analysis completed successfully.
# domain
# benzinga.com              7937
# gmail.com                  139
# andyswan.com                 5
# investdiva.com               2
# tothetick.com                2
# eosdetroit.io                1
# forextraininggroup.com       1
# stockmetrix.net              1
# Name: count, dtype: int64
